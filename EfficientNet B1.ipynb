# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import math
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

import keras
from tensorflow import keras
from keras import Sequential
from keras import layers
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams['figure.dpi'] = 300
colors = ["#B6EE56", "#D85F9C", "#EEA756", "#56EEE8"]

# %%
class_dist = {}
def image_counter(folder_path):
    basename = os.path.basename(folder_path)
    print('\033[92m'+f"A search has been initiated within the folder named '{basename}'."+'\033[0m')
    image_extensions = ['.jpg', '.jpeg', '.png']

    for root, dirs, _ in os.walk(folder_path):
        for dir_name in dirs:
            dir_path = os.path.join(root, dir_name)
            count = 0

            for filename in os.listdir(dir_path):
                file_ext = os.path.splitext(filename)[1].lower()

                if file_ext in image_extensions:
                    count += 1

            class_dist[dir_name] = count
            print(f"There are \033[35m{count}\033[0m images in the {dir_name} folder.")
    print('\033[92m'+"The search has been completed."+'\033[0m')

    keys = list(class_dist.keys())
    values = list(class_dist.values())
    explode = (0.1,)*len(keys)

    labels = [f'{key} ({value} images)' for key, value in zip(keys, values)]

    plt.pie(values, labels=labels, autopct='%1.1f%%',
            shadow=False, startangle=-90, colors=["skyblue", "lightblue", "violet", "pink"], textprops={'fontsize': 11, "fontweight" : "bold", "color":"black"},  wedgeprops=
           {'edgecolor':'black'} , labeldistance=1.05)
    plt.title("Distribution of \nAlzheimer MRI Images", size=12, fontweight="bold", color="blue")
PATH_train = '/kaggle/input/ad-train-test-validate-4-classes/train'
image_counter(PATH_train)
# Out:
# A search has been initiated within the folder named 'train'.
# There are 1322 images in the ModerateDemented folder.
# There are 1947 images in the NonDemented folder.
# There are 1834 images in the VeryMildDemented folder.
# There are 1826 images in the MildDemented folder.
# The search has been completed.

# %%
PATH_test = '/kaggle/input/ad-train-test-validate-4-classes/test'
image_counter(PATH_test)
# Out:
# A search has been initiated within the folder named 'test'.
# There are 526 images in the ModerateDemented folder.
# There are 799 images in the NonDemented folder.
# There are 769 images in the VeryMildDemented folder.
# There are 782 images in the MildDemented folder.
# The search has been completed.

# %%
PATH_validate = '/kaggle/input/ad-train-test-validate-4-classes/valid'
image_counter(PATH_validate)
# Out:
# A search has been initiated within the folder named 'valid'.
# There are 14 images in the ModerateDemented folder.
# There are 28 images in the NonDemented folder.
# There are 26 images in the VeryMildDemented folder.
# There are 27 images in the MildDemented folder.
# The search has been completed.

# %%
train_data = tf.keras.utils.image_dataset_from_directory(PATH_train,
                                                batch_size = 64,
                                                image_size=(240, 240),
                                                shuffle=True,
                                                seed=42,)
test_data = tf.keras.utils.image_dataset_from_directory(PATH_test,
                                                batch_size = 64,
                                                image_size=(240, 240),
                                                shuffle=True,
                                                seed=42,)
validate_data = tf.keras.utils.image_dataset_from_directory(PATH_validate,
                                                batch_size = 64,
                                                image_size=(240, 240),
                                                shuffle=True,
                                                seed=42,)
class_names = train_data.class_names
# Out:
# Found 6929 files belonging to 4 classes.
# Found 2876 files belonging to 4 classes.
# Found 95 files belonging to 4 classes.

# %%
alz_dict = {index: img for index, img in enumerate(train_data.class_names)}

class Process:
    def __init__(self, data):
        self.data = data.map(lambda x, y: (x/255, y))

    def create_new_batch(self):
        self.batch = self.data.as_numpy_iterator().next()
        text = "Min and max pixel values in the batch ->"
        print(text, self.batch[0].min(), "&", self.batch[0].max())

    def show_batch_images(self, number_of_images=5):
        fig, ax = plt.subplots(ncols=number_of_images, figsize=(20,20), facecolor="white")
        fig.suptitle("Brain MRI (Alzheimer) Samples in the Batch", color="black",fontsize=18, fontweight='bold', y=0.6)
        for idx, img in enumerate(self.batch[0][:number_of_images]):
            ax[idx].imshow(img)
            class_no = self.batch[1][idx]
            ax[idx].set_title(alz_dict[class_no], color="green", fontsize=16)
            ax[idx].set_xticklabels([])
            ax[idx].set_yticklabels([])

train_process = Process(train_data)
train_process.create_new_batch()
train_process.show_batch_images(number_of_images=5)

test_process = Process(test_data)
test_process.create_new_batch()
test_process.show_batch_images(number_of_images=5)

validate_process = Process(validate_data)
validate_process.create_new_batch()
validate_process.show_batch_images(number_of_images=5)
# Out:
# Min and max pixel values in the batch -> 0.0 & 1.0
# Min and max pixel values in the batch -> 0.0 & 1.0
# Min and max pixel values in the batch -> 0.0 & 1.0

# %%
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
def build_model():
    base_model = EfficientNetB1(weights='imagenet', include_top=False, input_shape=(240,240,3))
    for layer in base_model.layers:
        layer.trainable = False

    input_layer = Input(shape=(240, 240, 3))
    x = base_model(input_layer)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(16, activation='relu')(x)
    x = Dropout(0.2)(x)
    output = Dense(4, activation='softmax')(x)
    model = Model(input_layer, output)
    
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=['accuracy'])
    model.summary()
    return model
model = build_model()

def checkpoint_callback():
    checkpoint_filepath = '/tmp/checkpoint/model_checkpoint.keras'

    model_checkpoint_callback = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=False,
        save_freq='epoch',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )

    return model_checkpoint_callback

def early_stopping(patience):
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=1)
    return es_callback

checkpoint_callback = checkpoint_callback()
early_stopping = early_stopping(patience=5)
callbacks = [checkpoint_callback, early_stopping]

EPOCHS = 100
history = model.fit(train_data, epochs = EPOCHS, validation_data = validate_data)
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 240, 240, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb1 (Functional)     │ (None, 8, 8, 1280)     │     6,575,239 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 16)             │        20,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,600,923 (25.18 MB)
#  Trainable params: 23,124 (90.33 KB)
#  Non-trainable params: 6,577,799 (25.09 MB)
# Epoch 1/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 453ms/step - accuracy: 0.4310 - loss: 1.2789 - val_accuracy: 0.5579 - val_loss: 1.1105
# Epoch 2/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.5953 - loss: 0.9221 - val_accuracy: 0.6000 - val_loss: 0.9633
# Epoch 3/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.6281 - loss: 0.8160 - val_accuracy: 0.6632 - val_loss: 0.8038
# Epoch 4/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.6514 - loss: 0.7713 - val_accuracy: 0.6737 - val_loss: 0.7359
# Epoch 5/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.6805 - loss: 0.7159 - val_accuracy: 0.6842 - val_loss: 0.6729
# Epoch 6/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.6816 - loss: 0.7041 - val_accuracy: 0.7053 - val_loss: 0.6025
# Epoch 7/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.6899 - loss: 0.6757 - val_accuracy: 0.7053 - val_loss: 0.5885
# Epoch 8/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.6914 - loss: 0.6626 - val_accuracy: 0.6947 - val_loss: 0.5768
# Epoch 9/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7071 - loss: 0.6490 - val_accuracy: 0.7579 - val_loss: 0.5287
# Epoch 10/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7135 - loss: 0.6141 - val_accuracy: 0.7684 - val_loss: 0.5366
# Epoch 11/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.7183 - loss: 0.6321 - val_accuracy: 0.7789 - val_loss: 0.5052
# Epoch 12/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7369 - loss: 0.5930 - val_accuracy: 0.7895 - val_loss: 0.5443
# Epoch 13/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7371 - loss: 0.5848 - val_accuracy: 0.8211 - val_loss: 0.5064
# Epoch 14/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7413 - loss: 0.5753 - val_accuracy: 0.8211 - val_loss: 0.5174
# Epoch 15/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7404 - loss: 0.5909 - val_accuracy: 0.8000 - val_loss: 0.4740
# Epoch 16/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.7402 - loss: 0.5798 - val_accuracy: 0.7579 - val_loss: 0.5242
# Epoch 17/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.7580 - loss: 0.5582 - val_accuracy: 0.8105 - val_loss: 0.4819
# Epoch 18/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7461 - loss: 0.5595 - val_accuracy: 0.7789 - val_loss: 0.5184
# Epoch 19/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7632 - loss: 0.5406 - val_accuracy: 0.8000 - val_loss: 0.4329
# Epoch 20/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7587 - loss: 0.5495 - val_accuracy: 0.8105 - val_loss: 0.4637
# Epoch 21/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7509 - loss: 0.5508 - val_accuracy: 0.8000 - val_loss: 0.4882
# Epoch 22/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7677 - loss: 0.5337 - val_accuracy: 0.8000 - val_loss: 0.4921
# Epoch 23/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7507 - loss: 0.5390 - val_accuracy: 0.8316 - val_loss: 0.4357
# Epoch 24/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7660 - loss: 0.5413 - val_accuracy: 0.8211 - val_loss: 0.4466
# Epoch 25/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7670 - loss: 0.5316 - val_accuracy: 0.8105 - val_loss: 0.4418
# Epoch 26/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7754 - loss: 0.5117 - val_accuracy: 0.8105 - val_loss: 0.4466
# Epoch 27/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7757 - loss: 0.5034 - val_accuracy: 0.8105 - val_loss: 0.4414
# Epoch 28/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7659 - loss: 0.5100 - val_accuracy: 0.8105 - val_loss: 0.4128
# Epoch 29/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.7830 - loss: 0.4968 - val_accuracy: 0.8105 - val_loss: 0.4211
# Epoch 30/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7843 - loss: 0.4983 - val_accuracy: 0.8000 - val_loss: 0.4055
# Epoch 31/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7808 - loss: 0.4985 - val_accuracy: 0.8211 - val_loss: 0.3938
# Epoch 32/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7827 - loss: 0.4952 - val_accuracy: 0.8000 - val_loss: 0.3922
# Epoch 33/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7862 - loss: 0.4773 - val_accuracy: 0.8105 - val_loss: 0.4453
# Epoch 34/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7775 - loss: 0.5087 - val_accuracy: 0.8526 - val_loss: 0.3975
# Epoch 35/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7895 - loss: 0.4830 - val_accuracy: 0.8105 - val_loss: 0.4461
# Epoch 36/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.7829 - loss: 0.4802 - val_accuracy: 0.7895 - val_loss: 0.4201
# Epoch 37/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7850 - loss: 0.4840 - val_accuracy: 0.8316 - val_loss: 0.3873
# Epoch 38/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7875 - loss: 0.4852 - val_accuracy: 0.8316 - val_loss: 0.3969
# Epoch 39/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7873 - loss: 0.4690 - val_accuracy: 0.7895 - val_loss: 0.4372
# Epoch 40/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7877 - loss: 0.4793 - val_accuracy: 0.8526 - val_loss: 0.4049
# Epoch 41/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7854 - loss: 0.4835 - val_accuracy: 0.8211 - val_loss: 0.4048
# Epoch 42/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7983 - loss: 0.4599 - val_accuracy: 0.8526 - val_loss: 0.4513
# Epoch 43/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7928 - loss: 0.4584 - val_accuracy: 0.8211 - val_loss: 0.3984
# Epoch 44/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7751 - loss: 0.4860 - val_accuracy: 0.7895 - val_loss: 0.3655
# Epoch 45/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7886 - loss: 0.4676 - val_accuracy: 0.8316 - val_loss: 0.4329
# Epoch 46/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7981 - loss: 0.4532 - val_accuracy: 0.7789 - val_loss: 0.3843
# Epoch 47/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7946 - loss: 0.4585 - val_accuracy: 0.8000 - val_loss: 0.4016
# Epoch 48/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8055 - loss: 0.4477 - val_accuracy: 0.8211 - val_loss: 0.3773
# Epoch 49/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7971 - loss: 0.4548 - val_accuracy: 0.8211 - val_loss: 0.3846
# Epoch 50/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8044 - loss: 0.4500 - val_accuracy: 0.8000 - val_loss: 0.4066
# Epoch 51/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8009 - loss: 0.4507 - val_accuracy: 0.8316 - val_loss: 0.4337
# Epoch 52/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8142 - loss: 0.4350 - val_accuracy: 0.8316 - val_loss: 0.3779
# Epoch 53/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7926 - loss: 0.4562 - val_accuracy: 0.8105 - val_loss: 0.4287
# Epoch 54/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8082 - loss: 0.4403 - val_accuracy: 0.8526 - val_loss: 0.3453
# Epoch 55/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8064 - loss: 0.4451 - val_accuracy: 0.8105 - val_loss: 0.4378
# Epoch 56/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8084 - loss: 0.4242 - val_accuracy: 0.8316 - val_loss: 0.3711
# Epoch 57/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8088 - loss: 0.4252 - val_accuracy: 0.8421 - val_loss: 0.3391
# Epoch 58/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7924 - loss: 0.4605 - val_accuracy: 0.8526 - val_loss: 0.3429
# Epoch 59/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8038 - loss: 0.4489 - val_accuracy: 0.8211 - val_loss: 0.3763
# Epoch 60/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8022 - loss: 0.4423 - val_accuracy: 0.8842 - val_loss: 0.3717
# Epoch 61/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8183 - loss: 0.4233 - val_accuracy: 0.8105 - val_loss: 0.3344
# Epoch 62/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.7966 - loss: 0.4578 - val_accuracy: 0.8632 - val_loss: 0.3137
# Epoch 63/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8089 - loss: 0.4399 - val_accuracy: 0.8421 - val_loss: 0.3763
# Epoch 64/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8047 - loss: 0.4322 - val_accuracy: 0.8632 - val_loss: 0.3681
# Epoch 65/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8161 - loss: 0.4213 - val_accuracy: 0.8632 - val_loss: 0.3511
# Epoch 66/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8235 - loss: 0.4203 - val_accuracy: 0.8421 - val_loss: 0.3786
# Epoch 67/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8084 - loss: 0.4506 - val_accuracy: 0.8526 - val_loss: 0.3406
# Epoch 68/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8078 - loss: 0.4376 - val_accuracy: 0.8526 - val_loss: 0.3718
# Epoch 69/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8198 - loss: 0.4196 - val_accuracy: 0.8526 - val_loss: 0.3493
# Epoch 70/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8202 - loss: 0.4174 - val_accuracy: 0.8421 - val_loss: 0.3748
# Epoch 71/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8079 - loss: 0.4278 - val_accuracy: 0.8632 - val_loss: 0.3314
# Epoch 72/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8140 - loss: 0.4227 - val_accuracy: 0.8526 - val_loss: 0.3687
# Epoch 73/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8210 - loss: 0.4086 - val_accuracy: 0.8632 - val_loss: 0.3518
# Epoch 74/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8170 - loss: 0.4136 - val_accuracy: 0.8632 - val_loss: 0.3689
# Epoch 75/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8107 - loss: 0.4394 - val_accuracy: 0.8632 - val_loss: 0.3711
# Epoch 76/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8143 - loss: 0.4181 - val_accuracy: 0.8842 - val_loss: 0.3107
# Epoch 77/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8166 - loss: 0.4179 - val_accuracy: 0.8526 - val_loss: 0.3595
# Epoch 78/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8141 - loss: 0.4227 - val_accuracy: 0.8526 - val_loss: 0.4406
# Epoch 79/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8090 - loss: 0.4212 - val_accuracy: 0.8316 - val_loss: 0.3874
# Epoch 80/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8187 - loss: 0.4154 - val_accuracy: 0.8421 - val_loss: 0.3598
# Epoch 81/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8101 - loss: 0.4274 - val_accuracy: 0.8737 - val_loss: 0.3171
# Epoch 82/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8155 - loss: 0.4282 - val_accuracy: 0.8737 - val_loss: 0.3270
# Epoch 83/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8139 - loss: 0.4236 - val_accuracy: 0.8842 - val_loss: 0.3160
# Epoch 84/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8211 - loss: 0.4063 - val_accuracy: 0.8526 - val_loss: 0.3732
# Epoch 85/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8140 - loss: 0.4165 - val_accuracy: 0.8526 - val_loss: 0.3606
# Epoch 86/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8169 - loss: 0.4018 - val_accuracy: 0.8421 - val_loss: 0.3591
# Epoch 87/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8168 - loss: 0.4182 - val_accuracy: 0.8842 - val_loss: 0.3757
# Epoch 88/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8175 - loss: 0.4096 - val_accuracy: 0.8316 - val_loss: 0.4188
# Epoch 89/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8158 - loss: 0.4180 - val_accuracy: 0.8737 - val_loss: 0.3251
# Epoch 90/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8253 - loss: 0.4094 - val_accuracy: 0.8842 - val_loss: 0.3742
# Epoch 91/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8019 - loss: 0.4468 - val_accuracy: 0.8526 - val_loss: 0.3365
# Epoch 92/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8226 - loss: 0.4126 - val_accuracy: 0.8737 - val_loss: 0.3620
# Epoch 93/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8191 - loss: 0.4197 - val_accuracy: 0.8632 - val_loss: 0.3181
# Epoch 94/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8269 - loss: 0.4022 - val_accuracy: 0.8842 - val_loss: 0.3286
# Epoch 95/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8196 - loss: 0.4095 - val_accuracy: 0.8632 - val_loss: 0.3319
# Epoch 96/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8102 - loss: 0.4229 - val_accuracy: 0.8211 - val_loss: 0.4154
# Epoch 97/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8269 - loss: 0.4011 - val_accuracy: 0.8526 - val_loss: 0.3636
# Epoch 98/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8106 - loss: 0.4188 - val_accuracy: 0.8526 - val_loss: 0.4207
# Epoch 99/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8199 - loss: 0.4088 - val_accuracy: 0.8211 - val_loss: 0.4112
# Epoch 100/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8265 - loss: 0.4081 - val_accuracy: 0.8316 - val_loss: 0.3652

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6), facecolor="lightblue")
ax[0].set_facecolor('ivory')
ax[0].set_title('Loss', fontweight="bold")
ax[0].set_xlabel("Epoch", size=14)
ax[0].plot(history.epoch, history.history["loss"], label="Train Loss", color="red")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation Loss", color="green", linestyle="dashed")
ax[0].legend()
ax[1].set_facecolor('ivory')
ax[1].set_title('Accuracy', fontweight="bold")
ax[1].set_xlabel("Epoch", size=14)
ax[1].plot(history.epoch, history.history["accuracy"], label="Train Acc.", color="red")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation Acc.", color="green", linestyle="dashed")
ax[1].legend()

# %%
model.evaluate(test_data)

predictions = []
labels = []

for X, y in test_data.as_numpy_iterator():
    y_pred = model.predict(X, verbose=0)
    y_prediction = np.argmax(y_pred, axis=1)
    predictions.extend(y_prediction)
    labels.extend(y)

predictions = np.array(predictions)
labels = np.array(labels)

print(classification_report(labels, predictions, target_names=class_names, digits = 5))

cm = confusion_matrix(labels, predictions)
cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
cm_df
plt.figure(figsize=(10,6), dpi=300)
sns.heatmap(cm_df, annot=True, cmap="PuBu", fmt=".1f")
plt.title("Confusion Matrix", fontweight="bold")
plt.xlabel("Predicted", fontweight="bold")
plt.ylabel("True", fontweight="bold")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 192ms/step - accuracy: 0.8352 - loss: 0.4228
#                   precision    recall  f1-score   support
#
#     MildDemented    0.86744   0.86189   0.86466       782
# ModerateDemented    0.97757   0.99430   0.98586       526
#      NonDemented    0.82781   0.78223   0.80438       799
# VeryMildDemented    0.75031   0.78934   0.76933       769
#
#         accuracy                        0.84458      2876
#        macro avg    0.85578   0.85694   0.85606      2876
#     weighted avg    0.84525   0.84458   0.84459      2876
# Text(287.1666666666666, 0.5, 'True')
