# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import math
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

import keras
from tensorflow import keras
from keras import Sequential
from keras import layers
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Dropout, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams['figure.dpi'] = 300
colors = ["#B6EE56", "#D85F9C", "#EEA756", "#56EEE8"]

# %%
class_dist = {}
def image_counter(folder_path):
    basename = os.path.basename(folder_path)
    print('\033[92m'+f"A search has been initiated within the folder named '{basename}'."+'\033[0m')
    image_extensions = ['.jpg', '.jpeg', '.png']

    for root, dirs, _ in os.walk(folder_path):
        for dir_name in dirs:
            dir_path = os.path.join(root, dir_name)
            count = 0

            for filename in os.listdir(dir_path):
                file_ext = os.path.splitext(filename)[1].lower()

                if file_ext in image_extensions:
                    count += 1

            class_dist[dir_name] = count
            print(f"There are \033[35m{count}\033[0m images in the {dir_name} folder.")
    print('\033[92m'+"The search has been completed."+'\033[0m')

    keys = list(class_dist.keys())
    values = list(class_dist.values())
    explode = (0.1,)*len(keys)

    labels = [f'{key} ({value} images)' for key, value in zip(keys, values)]

    plt.pie(values, labels=labels, autopct='%1.1f%%',
            shadow=False, startangle=-90, colors=["skyblue", "lightblue", "violet", "pink"], textprops={'fontsize': 11, "fontweight" : "bold", "color":"black"},  wedgeprops=
           {'edgecolor':'black'} , labeldistance=1.05)
    plt.title("Distribution of \nAlzheimer MRI Images", size=12, fontweight="bold", color="blue")
PATH_train = '/kaggle/input/ad-train-test-validate-4-classes/train'
image_counter(PATH_train)
# Out:
# A search has been initiated within the folder named 'train'.
# There are 1322 images in the ModerateDemented folder.
# There are 1947 images in the NonDemented folder.
# There are 1834 images in the VeryMildDemented folder.
# There are 1826 images in the MildDemented folder.
# The search has been completed.

# %%
PATH_test = '/kaggle/input/ad-train-test-validate-4-classes/test'
image_counter(PATH_test)
# Out:
# A search has been initiated within the folder named 'test'.
# There are 526 images in the ModerateDemented folder.
# There are 799 images in the NonDemented folder.
# There are 769 images in the VeryMildDemented folder.
# There are 782 images in the MildDemented folder.
# The search has been completed.

# %%
PATH_validate = '/kaggle/input/ad-train-test-validate-4-classes/valid'
image_counter(PATH_validate)
# Out:
# A search has been initiated within the folder named 'valid'.
# There are 14 images in the ModerateDemented folder.
# There are 28 images in the NonDemented folder.
# There are 26 images in the VeryMildDemented folder.
# There are 27 images in the MildDemented folder.
# The search has been completed.

# %%
train_data = tf.keras.utils.image_dataset_from_directory(PATH_train,
                                                batch_size = 64,
                                                image_size=(260, 260),
                                                shuffle=True,
                                                seed=42,)
test_data = tf.keras.utils.image_dataset_from_directory(PATH_test,
                                                batch_size = 64,
                                                image_size=(260, 260),
                                                shuffle=True,
                                                seed=42,)
validate_data = tf.keras.utils.image_dataset_from_directory(PATH_validate,
                                                batch_size = 64,
                                                image_size=(260, 260),
                                                shuffle=True,
                                                seed=42,)
class_names = train_data.class_names
# Out:
# Found 6929 files belonging to 4 classes.
# Found 2876 files belonging to 4 classes.
# Found 95 files belonging to 4 classes.

# %%
alz_dict = {index: img for index, img in enumerate(train_data.class_names)}

class Process:
    def __init__(self, data):
        self.data = data.map(lambda x, y: (x/255, y))

    def create_new_batch(self):
        self.batch = self.data.as_numpy_iterator().next()
        text = "Min and max pixel values in the batch ->"
        print(text, self.batch[0].min(), "&", self.batch[0].max())

    def show_batch_images(self, number_of_images=5):
        fig, ax = plt.subplots(ncols=number_of_images, figsize=(20,20), facecolor="white")
        fig.suptitle("Brain MRI (Alzheimer) Samples in the Batch", color="black",fontsize=18, fontweight='bold', y=0.6)
        for idx, img in enumerate(self.batch[0][:number_of_images]):
            ax[idx].imshow(img)
            class_no = self.batch[1][idx]
            ax[idx].set_title(alz_dict[class_no], color="green", fontsize=16)
            ax[idx].set_xticklabels([])
            ax[idx].set_yticklabels([])

train_process = Process(train_data)
train_process.create_new_batch()
train_process.show_batch_images(number_of_images=5)

test_process = Process(test_data)
test_process.create_new_batch()
test_process.show_batch_images(number_of_images=5)

validate_process = Process(validate_data)
validate_process.create_new_batch()
validate_process.show_batch_images(number_of_images=5)
# Out:
# Min and max pixel values in the batch -> 0.0 & 1.0
# Min and max pixel values in the batch -> 0.0 & 1.0
# Min and max pixel values in the batch -> 0.0 & 1.0

# %%
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
def build_model():
    base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(260,260,3))
    for layer in base_model.layers:
        layer.trainable = False

    input_layer = Input(shape=(260, 260, 3))
    x = base_model(input_layer)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(32, activation='relu')(x)
    x = Dropout(0.2)(x)
    output = Dense(4, activation='softmax')(x)
    model = Model(input_layer, output)
    
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=['accuracy'])
    model.summary()
    return model
model = build_model()

def checkpoint_callback():
    checkpoint_filepath = '/tmp/checkpoint/model_checkpoint.keras'

    model_checkpoint_callback = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=False,
        save_freq='epoch',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )

    return model_checkpoint_callback

def early_stopping(patience):
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, verbose=1)
    return es_callback

checkpoint_callback = checkpoint_callback()
early_stopping = early_stopping(patience=5)
callbacks = [checkpoint_callback, early_stopping]

EPOCHS = 100
history = model.fit(train_data, epochs = EPOCHS, validation_data = validate_data)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 260, 260, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb2 (Functional)     │ (None, 9, 9, 1408)     │     7,768,569 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1408)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1408)           │         5,632 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │        45,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,819,421 (29.83 MB)
#  Trainable params: 48,036 (187.64 KB)
#  Non-trainable params: 7,771,385 (29.65 MB)
# Epoch 1/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 97s 485ms/step - accuracy: 0.4388 - loss: 1.3378 - val_accuracy: 0.6000 - val_loss: 1.1092
# Epoch 2/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.6123 - loss: 0.8843 - val_accuracy: 0.6526 - val_loss: 0.9490
# Epoch 3/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.6574 - loss: 0.7766 - val_accuracy: 0.6316 - val_loss: 0.7770
# Epoch 4/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.6921 - loss: 0.7110 - val_accuracy: 0.6842 - val_loss: 0.6858
# Epoch 5/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.6932 - loss: 0.6817 - val_accuracy: 0.6947 - val_loss: 0.6751
# Epoch 6/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7065 - loss: 0.6540 - val_accuracy: 0.6842 - val_loss: 0.6098
# Epoch 7/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7324 - loss: 0.6217 - val_accuracy: 0.7263 - val_loss: 0.6187
# Epoch 8/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7440 - loss: 0.5902 - val_accuracy: 0.7368 - val_loss: 0.6039
# Epoch 9/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7446 - loss: 0.5916 - val_accuracy: 0.7684 - val_loss: 0.5759
# Epoch 10/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.7556 - loss: 0.5737 - val_accuracy: 0.7474 - val_loss: 0.5507
# Epoch 11/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7580 - loss: 0.5541 - val_accuracy: 0.7263 - val_loss: 0.6450
# Epoch 12/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7582 - loss: 0.5571 - val_accuracy: 0.7684 - val_loss: 0.5314
# Epoch 13/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7805 - loss: 0.5267 - val_accuracy: 0.7684 - val_loss: 0.5624
# Epoch 14/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7650 - loss: 0.5352 - val_accuracy: 0.7474 - val_loss: 0.5318
# Epoch 15/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7845 - loss: 0.5107 - val_accuracy: 0.7368 - val_loss: 0.5896
# Epoch 16/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7763 - loss: 0.5093 - val_accuracy: 0.7579 - val_loss: 0.5804
# Epoch 17/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7953 - loss: 0.4796 - val_accuracy: 0.7684 - val_loss: 0.5447
# Epoch 18/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7934 - loss: 0.4712 - val_accuracy: 0.7579 - val_loss: 0.5644
# Epoch 19/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7954 - loss: 0.4765 - val_accuracy: 0.7579 - val_loss: 0.4829
# Epoch 20/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.7918 - loss: 0.4943 - val_accuracy: 0.7474 - val_loss: 0.4904
# Epoch 21/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.7948 - loss: 0.4745 - val_accuracy: 0.7579 - val_loss: 0.4920
# Epoch 22/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8136 - loss: 0.4478 - val_accuracy: 0.7789 - val_loss: 0.5313
# Epoch 23/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8112 - loss: 0.4389 - val_accuracy: 0.7684 - val_loss: 0.5867
# Epoch 24/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8068 - loss: 0.4525 - val_accuracy: 0.7789 - val_loss: 0.4892
# Epoch 25/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8158 - loss: 0.4403 - val_accuracy: 0.8000 - val_loss: 0.5172
# Epoch 26/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8189 - loss: 0.4161 - val_accuracy: 0.8105 - val_loss: 0.4334
# Epoch 27/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8287 - loss: 0.4118 - val_accuracy: 0.7895 - val_loss: 0.4650
# Epoch 28/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8203 - loss: 0.4289 - val_accuracy: 0.8105 - val_loss: 0.3928
# Epoch 29/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.8193 - loss: 0.4242 - val_accuracy: 0.8000 - val_loss: 0.4595
# Epoch 30/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8232 - loss: 0.4081 - val_accuracy: 0.8105 - val_loss: 0.4316
# Epoch 31/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8345 - loss: 0.3955 - val_accuracy: 0.8105 - val_loss: 0.4721
# Epoch 32/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8357 - loss: 0.3949 - val_accuracy: 0.7789 - val_loss: 0.4482
# Epoch 33/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8311 - loss: 0.3972 - val_accuracy: 0.8105 - val_loss: 0.5116
# Epoch 34/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8272 - loss: 0.4042 - val_accuracy: 0.7789 - val_loss: 0.4379
# Epoch 35/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8284 - loss: 0.3940 - val_accuracy: 0.8105 - val_loss: 0.4395
# Epoch 36/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8356 - loss: 0.3817 - val_accuracy: 0.8105 - val_loss: 0.4323
# Epoch 37/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8375 - loss: 0.3946 - val_accuracy: 0.7895 - val_loss: 0.4321
# Epoch 38/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8486 - loss: 0.3657 - val_accuracy: 0.8000 - val_loss: 0.4928
# Epoch 39/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8556 - loss: 0.3581 - val_accuracy: 0.7789 - val_loss: 0.4568
# Epoch 40/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8463 - loss: 0.3669 - val_accuracy: 0.7895 - val_loss: 0.4282
# Epoch 41/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8408 - loss: 0.3684 - val_accuracy: 0.7789 - val_loss: 0.4529
# Epoch 42/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8431 - loss: 0.3702 - val_accuracy: 0.8105 - val_loss: 0.4307
# Epoch 43/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8419 - loss: 0.3739 - val_accuracy: 0.8105 - val_loss: 0.5270
# Epoch 44/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8467 - loss: 0.3667 - val_accuracy: 0.8421 - val_loss: 0.4567
# Epoch 45/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8505 - loss: 0.3470 - val_accuracy: 0.8105 - val_loss: 0.3683
# Epoch 46/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8572 - loss: 0.3463 - val_accuracy: 0.8000 - val_loss: 0.4433
# Epoch 47/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8450 - loss: 0.3766 - val_accuracy: 0.8000 - val_loss: 0.4811
# Epoch 48/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8537 - loss: 0.3413 - val_accuracy: 0.8316 - val_loss: 0.4315
# Epoch 49/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8480 - loss: 0.3589 - val_accuracy: 0.8211 - val_loss: 0.5064
# Epoch 50/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8583 - loss: 0.3438 - val_accuracy: 0.8000 - val_loss: 0.4075
# Epoch 51/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8548 - loss: 0.3500 - val_accuracy: 0.8105 - val_loss: 0.4225
# Epoch 52/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8469 - loss: 0.3570 - val_accuracy: 0.8316 - val_loss: 0.4223
# Epoch 53/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8661 - loss: 0.3249 - val_accuracy: 0.8316 - val_loss: 0.4998
# Epoch 54/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8571 - loss: 0.3446 - val_accuracy: 0.8211 - val_loss: 0.3891
# Epoch 55/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8551 - loss: 0.3548 - val_accuracy: 0.8316 - val_loss: 0.4511
# Epoch 56/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8620 - loss: 0.3324 - val_accuracy: 0.8105 - val_loss: 0.4377
# Epoch 57/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8679 - loss: 0.3273 - val_accuracy: 0.8316 - val_loss: 0.3923
# Epoch 58/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8613 - loss: 0.3383 - val_accuracy: 0.8105 - val_loss: 0.3725
# Epoch 59/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8552 - loss: 0.3338 - val_accuracy: 0.8211 - val_loss: 0.5198
# Epoch 60/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8630 - loss: 0.3223 - val_accuracy: 0.8105 - val_loss: 0.3325
# Epoch 61/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8642 - loss: 0.3176 - val_accuracy: 0.8211 - val_loss: 0.3990
# Epoch 62/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8684 - loss: 0.3191 - val_accuracy: 0.8421 - val_loss: 0.3451
# Epoch 63/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8650 - loss: 0.3298 - val_accuracy: 0.8000 - val_loss: 0.5050
# Epoch 64/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8647 - loss: 0.3283 - val_accuracy: 0.8316 - val_loss: 0.4050
# Epoch 65/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8676 - loss: 0.3241 - val_accuracy: 0.8211 - val_loss: 0.4040
# Epoch 66/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8605 - loss: 0.3346 - val_accuracy: 0.8105 - val_loss: 0.4172
# Epoch 67/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8739 - loss: 0.3147 - val_accuracy: 0.8211 - val_loss: 0.3622
# Epoch 68/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8650 - loss: 0.3349 - val_accuracy: 0.8526 - val_loss: 0.3795
# Epoch 69/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8692 - loss: 0.3034 - val_accuracy: 0.8421 - val_loss: 0.3753
# Epoch 70/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8670 - loss: 0.3273 - val_accuracy: 0.8526 - val_loss: 0.3620
# Epoch 71/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8676 - loss: 0.3180 - val_accuracy: 0.8526 - val_loss: 0.3456
# Epoch 72/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8741 - loss: 0.3061 - val_accuracy: 0.8211 - val_loss: 0.4844
# Epoch 73/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8772 - loss: 0.3018 - val_accuracy: 0.8526 - val_loss: 0.3742
# Epoch 74/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8753 - loss: 0.3035 - val_accuracy: 0.8211 - val_loss: 0.4596
# Epoch 75/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8791 - loss: 0.3006 - val_accuracy: 0.8737 - val_loss: 0.3506
# Epoch 76/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8749 - loss: 0.3082 - val_accuracy: 0.8105 - val_loss: 0.3867
# Epoch 77/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8782 - loss: 0.2894 - val_accuracy: 0.8421 - val_loss: 0.4350
# Epoch 78/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8718 - loss: 0.2960 - val_accuracy: 0.8316 - val_loss: 0.3583
# Epoch 79/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8698 - loss: 0.3203 - val_accuracy: 0.8316 - val_loss: 0.3958
# Epoch 80/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8774 - loss: 0.2905 - val_accuracy: 0.8526 - val_loss: 0.3744
# Epoch 81/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8727 - loss: 0.3046 - val_accuracy: 0.8421 - val_loss: 0.3897
# Epoch 82/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8702 - loss: 0.3088 - val_accuracy: 0.8316 - val_loss: 0.3509
# Epoch 83/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8829 - loss: 0.2791 - val_accuracy: 0.8737 - val_loss: 0.3486
# Epoch 84/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.8800 - loss: 0.2935 - val_accuracy: 0.8632 - val_loss: 0.3332
# Epoch 85/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8732 - loss: 0.3101 - val_accuracy: 0.8316 - val_loss: 0.3734
# Epoch 86/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8712 - loss: 0.3154 - val_accuracy: 0.8526 - val_loss: 0.3579
# Epoch 87/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - accuracy: 0.8729 - loss: 0.3089 - val_accuracy: 0.8632 - val_loss: 0.3567
# Epoch 88/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - accuracy: 0.8724 - loss: 0.2949 - val_accuracy: 0.8316 - val_loss: 0.3363
# Epoch 89/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8737 - loss: 0.3053 - val_accuracy: 0.8000 - val_loss: 0.4058
# Epoch 90/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8750 - loss: 0.2914 - val_accuracy: 0.8421 - val_loss: 0.3385
# Epoch 91/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8686 - loss: 0.2970 - val_accuracy: 0.8842 - val_loss: 0.3588
# Epoch 92/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8819 - loss: 0.2939 - val_accuracy: 0.8316 - val_loss: 0.3697
# Epoch 93/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8764 - loss: 0.2946 - val_accuracy: 0.8421 - val_loss: 0.3936
# Epoch 94/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8786 - loss: 0.2844 - val_accuracy: 0.8316 - val_loss: 0.3807
# Epoch 95/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8854 - loss: 0.2940 - val_accuracy: 0.8105 - val_loss: 0.3585
# Epoch 96/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - accuracy: 0.8858 - loss: 0.2885 - val_accuracy: 0.8421 - val_loss: 0.2932
# Epoch 97/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - accuracy: 0.8763 - loss: 0.3041 - val_accuracy: 0.8421 - val_loss: 0.3686
# Epoch 98/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 106ms/step - accuracy: 0.8772 - loss: 0.3036 - val_accuracy: 0.8421 - val_loss: 0.3601
# Epoch 99/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8798 - loss: 0.2901 - val_accuracy: 0.8421 - val_loss: 0.3642
# Epoch 100/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - accuracy: 0.8814 - loss: 0.2917 - val_accuracy: 0.8737 - val_loss: 0.3268

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6), facecolor="lightblue")
ax[0].set_facecolor('ivory')
ax[0].set_title('Loss', fontweight="bold")
ax[0].set_xlabel("Epoch", size=14)
ax[0].plot(history.epoch, history.history["loss"], label="Train Loss", color="red")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation Loss", color="green", linestyle="dashed")
ax[0].legend()
ax[1].set_facecolor('ivory')
ax[1].set_title('Accuracy', fontweight="bold")
ax[1].set_xlabel("Epoch", size=14)
ax[1].plot(history.epoch, history.history["accuracy"], label="Train Acc.", color="red")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation Acc.", color="green", linestyle="dashed")
ax[1].legend()

# %%
model.evaluate(test_data)

predictions = []
labels = []

for X, y in test_data.as_numpy_iterator():
    y_pred = model.predict(X, verbose=0)
    y_prediction = np.argmax(y_pred, axis=1)
    predictions.extend(y_prediction)
    labels.extend(y)

predictions = np.array(predictions)
labels = np.array(labels)

print(classification_report(labels, predictions, target_names=class_names, digits = 5))

cm = confusion_matrix(labels, predictions)
cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
cm_df
plt.figure(figsize=(10,6), dpi=300)
sns.heatmap(cm_df, annot=True, cmap="PuBu", fmt=".1f")
plt.title("Confusion Matrix", fontweight="bold")
plt.xlabel("Predicted", fontweight="bold")
plt.ylabel("True", fontweight="bold")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 23s 499ms/step - accuracy: 0.8936 - loss: 0.2930
#                   precision    recall  f1-score   support
#
#     MildDemented    0.89429   0.94118   0.91713       782
# ModerateDemented    0.99245   1.00000   0.99621       526
#      NonDemented    0.87196   0.85232   0.86203       799
# VeryMildDemented    0.84636   0.81664   0.83124       769
#
#         accuracy                        0.89395      2876
#        macro avg    0.90127   0.90253   0.90165      2876
#     weighted avg    0.89322   0.89395   0.89332      2876
# Text(287.1666666666666, 0.5, 'True')
